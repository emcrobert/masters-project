# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

from helpers import *
import tensorflow as tf
from tensorflow.keras import layers, Model

from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers.experimental import preprocessing
import matplotlib.pyplot as plt
import os

import warnings

filtered = list_ds = tf.data.experimental.load('datasets/filtered_filenames')
print("loaded dataset with " + str(tf.data.experimental.cardinality(filtered).numpy()) + " products")
counter = 1
for cur_filename in filtered:
    print(counter, cur_filename)
    counter+=1
"""
list_ds = tf.data.experimental.load('datasets/train_without_ratio')
print("loaded dataset with " + str(tf.data.experimental.cardinality(list_ds).numpy()) + " products")

rescaling_layer = Rescaling(scale = 1./1811.6)
list_ds = list_ds.map(lambda x, y: (x, rescaling_layer(y)))



counter = 0
for cur_element in list_ds:
    print("counter = " + str(counter))
    counter = counter + 1
    plt.figure(counter)
    
    plt.imshow(cur_element[1])
    if counter > 30:
        break
"""
# Out:
# tf.Tensor(b'../../data/HiltonOfFern_crop_field_training_cloud_free_available_area/20181015/ROI1/S2/Patches/S1_531e42bd-eadb-495e-ae77-e3242f5ed70e_S2_4d4ec32a-afff-40a3-b8a3-f0a23320a93c_1280_5376_256x256.tif', shape=(), dtype=string)
# tf.Tensor(b'../../data/HiltonOfFern_crop_field_training_cloud_free_available_area/20181015/ROI2/S2/Patches/S1_b48e338a-18d6-4739-95c9-6544f91882c8_S2_b37b676e-0570-4bab-977f-5a16e72572ff_1024_2304_256x256.tif', shape=(), dtype=string)
# tf.Tensor(b'../../data/HiltonOfFern_crop_field_training_cloud_free_available_area/20190722/ROI1/S2/Patches/S1_b609f77d-9814-4ed8-b2b2-85be531b25d9_S2_9e35728e-7d70-4313-9714-e5c75fd1bf33_2048_2304_256x256.tif', shape=(), dtype=string)
# tf.Tensor(b'../../data/HiltonOfFern_crop_field_training_cloud_free_available_area/20190225/ROI1/S2/Patches/S1_150c763c-0ee6-4611-a6ce-d9cc89f3420b_S2_d5bb8ed3-4ad7-4373-afd0-cfbfb5523da7_3072_2560_256x256.tif', shape=(), dtype=string)
# ...
