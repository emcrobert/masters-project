# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import rasterio.io
import pprint
import seaborn as sns
#import seaborn.histplot

HIGH_VALUE_CUT_OFF = 1348

DATASET_ROOT_PATH = '../../data/HiltonOfFern_crop_field_training_cloud_free_available_area/'
#pp = pprint.PrettyPrinter(indent=4)

# use seaborn default style settings which are probably prettier than anything I'd design
#sns.set_style("darkgrid")


def replace_no_data_in_array(sentinel_data, array, replace_value=0):
  array[array == sentinel_data.profile['nodata']] = replace_value
  return array

def is_outside_roi(all_bands, no_data_value):
    no_data_count = np.count_nonzero(all_bands == no_data_value)
    
    if no_data_count > 14319:
        return True
    return False
"""
red_test = np.array([1,2,3,4,5])
green_test = np.array([1,2,3,4,5])
blue_test = np.array([1,2,3,4,5])
all_test = np.dstack((red_test, green_test, blue_test))
if is_outside_roi(all_test, 5):
    print("outside region of interest")
"""


highest_cloud_value=0
highest_cloud_file=""
highest_cloud_shadow_value=0
highest_cloud_shadow_file=""

total_files = 0
outside_roi = 0
cloudy = 0
shadows = 0
sensor_errors = 0
max_seen = 0

file_max_values = {}
file_high_value_count = {}
file_average = {}
all_reds = np.array([])
all_greens = np.array([])
all_blues = np.array([])
no_data_vals = np.array([])
sensor_error_vals = np.array([])
cloud_shadow_vals = np.array([])
cloud_vals = np.array([])
all_vals = np.array([])

all_vh = np.array([])
all_vv = np.array([])
all_rad_vals = np.array([])

for cur_file in glob.glob(DATASET_ROOT_PATH + '/*/*/S2/Patches/*.tif'):

    #if cur_file.endswith("tif"):
    sentinel_data =  rasterio.open(cur_file)
    total_files = total_files + 1
    
    

    # load r,g & b values into 3 lists
    cur_red = replace_no_data_in_array(sentinel_data, sentinel_data.read(4))
    cur_green = replace_no_data_in_array(sentinel_data, sentinel_data.read(3))
    cur_blue = replace_no_data_in_array(sentinel_data, sentinel_data.read(2))

    cur_img = np.dstack((cur_red, cur_green, cur_blue))
    # convert list to numpy arrays
    #cur_img = np.asarray(cur_img)
    no_data_count = np.count_nonzero(cur_img == sentinel_data.profile['nodata'])
    #no_data_vals = np.append(no_data_vals,no_data_count)
    # check if outside roi
    if is_outside_roi(cur_img, sentinel_data.profile['nodata']):
        print(cur_file + " is outside ROI")
        outside_roi += 1
        
        continue

    # load cloud data
    medium_prob_cloud = sentinel_data.read(16)
    high_prod_cloud = sentinel_data.read(17)
    cirrus_cloud = sentinel_data.read(18)

    cloud_mask = np.dstack((medium_prob_cloud, high_prod_cloud, cirrus_cloud))  
    #cloud_mask = np.dstack((high_prod_cloud, cirrus_cloud))  
    #cloud_vals = np.append(cloud_vals, np.count_nonzero(cloud_mask))
    # check for cloud data
    non_zero_count = np.count_nonzero(cloud_mask)
    if non_zero_count > 6293:
        
        print("skipping images as " + str(non_zero_count) + " pixels are covered by cloud")
        #if non_zero_count > highest_cloud_value:
        #    highest_cloud_file = cur_file
        #    highest_cloud_value = non_zero_count
        #    print(cur_file + " has the most cloud pixels I've seen so far")
        cloudy += 1
        continue
    
    cloud_shadow = sentinel_data.read(15)
    
    
    #cloud_shadow_vals = np.append(cloud_shadow_vals,np.count_nonzero(cloud_shadow))
    
    shadow_nonzero_count = np.count_nonzero(cloud_shadow)
    """
    if shadow_nonzero_count > highest_cloud_shadow_value:
            highest_cloud_shadow_file = cur_file
            highest_cloud_shadow_value = shadow_nonzero_count
            print(cur_file + " has the most cloud shadow pixels I've seen so far")
    """        
    # if too many pixels are covered by cloud shadow skip image
    if shadow_nonzero_count > 6611:
        print("skipping image as " + str(shadow_nonzero_count) + " pixels are covered by shadow")
                 
        shadows += 1
        continue
    
    # get rid of images where more than 12.5% of the values seem to be sensor errors
    likely_sensor_errors = cur_img > 1348.0
    sensor_error_vals = np.append(sensor_error_vals, likely_sensor_errors)
    if likely_sensor_errors.sum() > float((cur_img.size * 0.125)):
        print("skipping image as " + str(likely_sensor_errors.sum()) + " pixels have sensors errors") 
        sensor_errors += 1
        continue
        
    #file_max_values[cur_file] = np.amax(cur_img)
    #file_average[cur_file] = np.average(cur_img)
    #file_high_value_count[cur_file] = np.count_nonzero(cur_img > HIGH_VALUE_CUT_OFF)

    #all_reds = np.append(all_reds,cur_red)
    #all_greens = np.append(all_greens,cur_green)
    #all_blues = np.append(all_blues,cur_blue)
    
    #all_vals = np.concatenate((all_vals, cur_img.flatten()))
    sentinel_data.close()
    
    """
    sen1_file = cur_file.replace("/S2/", "/S1/")
    sentinel1_data =  rasterio.open(sen1_file)
    cur_vh = replace_no_data_in_array(sentinel1_data, sentinel1_data.read(1))
    cur_vv = replace_no_data_in_array(sentinel1_data, sentinel1_data.read(2))
    
    #all_vh = np.append(all_vh,cur_vh)
    #all_vv = np.append(all_vv,cur_vv)
    cur_radar = np.dstack((cur_vh, cur_vv))
    # convert list to numpy arrays
    cur_radar = np.asarray(cur_radar)
    
    all_rad_vals = np.concatenate((all_rad_vals, cur_radar.flatten()))
    
    sentinel1_data.close()
    """
    
print("loaded " + str(total_files) + " files")
print("skipped " + str(outside_roi) + " files for being outside region of interest")
print("skipped " + str(cloudy) + " files for being cloudy")
print("skipped " + str(shadows) + " files for being in shadow")
print("skipped " + str(sensor_errors) + " files for having too many values which could be sensor errors")

remaining_files = total_files - outside_roi - cloudy - shadows - sensor_errors
print(str(remaining_files) + " files remaining")
"""
print("average amount of no data is " + str(np.average(no_data_vals)))
# print standard deviation

print("standard deviation is " + str(np.std(no_data_vals)))
print("2nd percentile is " +  str(np.percentile(no_data_vals,2)))
for cur_percentile in range(0,80,5):
    print(str(cur_percentile) + " percentile is " +  str(np.percentile(no_data_vals,cur_percentile)))

for cur_percentile in range(30,50):
    print(str(cur_percentile) + " percentile is " +  str(np.percentile(no_data_vals,cur_percentile)))
    

print("average amount of cloud shadow is " + str(np.average(cloud_shadow_vals)))
# print standard deviation

print("standard deviation is " + str(np.std(cloud_shadow_vals)))
for cur_percentile in range(0,80,5):
    print(str(cur_percentile) + " percentile for cloud shadow data is " +  str(np.percentile(cloud_shadow_vals,cur_percentile)))

for cur_percentile in range(75,90):
    print(str(cur_percentile) + " percentile for cloud shadow data is " +  str(np.percentile(cloud_shadow_vals,cur_percentile)))
    

print("average amount of cloud is " + str(np.average(cloud_vals)))
# print standard deviation

print("standard deviation is " + str(np.std(cloud_vals)))
for cur_percentile in range(0,75,5):
    print(str(cur_percentile) + " percentile for cloud data is " +  str(np.percentile(cloud_vals,cur_percentile)))

for cur_percentile in range(70,90):
    print(str(cur_percentile) + " percentile for cloud data is " +  str(np.percentile(cloud_vals,cur_percentile)))
# plot 3 histograms for rgb

all_reds = all_reds.flatten()


plt.figure(0)
plt.title("Probability Density of Red Values")
sns.distplot(all_reds, kde=True, hist=True, bins='auto', color='r')
plt.ylim(0,0.005)
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

all_greens = all_greens.flatten()

plt.figure(1)
plt.title("Probability Density of Green values")
sns.distplot(all_greens, kde=True, hist=True, bins='auto', color='g')
plt.ylim(0,0.005)
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

all_blues = all_blues.flatten()
plt.figure(2)
plt.title("Probability Density of Blue values")
sns.distplot(all_blues, kde=True, hist=True, bins='auto', color='b')
plt.ylim(0,0.005)
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()
"""
# plot histograms for sentinel 1 data
#all_vh = all_vh.flatten()


# print average value
#print("average sentinel 2 value is " + str(np.average(all_vals)))
# print standard deviation
#print("standard deviation is " + str(np.std(all_vals)))

# print average value
#print("average sentinel 1 value is " + str(np.average(all_rad_vals)))
# print standard deviation
#print("standard deviation is " + str(np.std(all_rad_vals)))



percentiles_to_print = [1,2,3,4,5,75,80,85,90,95,98]
"""
for cur_percent in percentiles_to_print:
    print(str(cur_percent) + "th percentile of Sentinel 2 data is " + str(np.percentile(all_vals, cur_percent)))

for cur_percent in percentiles_to_print:
    print(str(cur_percent) + "th percentile of Sentinel 1 data is " + str(np.percentile(all_rad_vals, cur_percent)))

for cur_percent in percentiles_to_print:
    print(str(cur_percent) + "th percentile of sensor errors " + str(np.percentile(sensor_error_vals, cur_percent)))
sensor_error_vals
"""  
# print max value
#print("maximum sentinel 2 value seen is " + str(np.amax(all_vals)))
#print("maximum sentinel 1 value seen is " + str(np.amax(all_rad_vals)))
"""
counter = 0
# list 10 files with highest max values
print("files with highest max values:")
for file in sorted(file_max_values, key=file_max_values.get, reverse=True):
    print(file + " had max value " + str(file_max_values[file]))
    counter = counter + 1
    if counter > 9:
        break
print("\n\n")
# list 10 files with most high values
counter = 0
print("files with most high values:")
for file in sorted(file_high_value_count, key=file_high_value_count.get, reverse=True):
    print(file + " had " + str(file_high_value_count[file]) + " values over " + str(HIGH_VALUE_CUT_OFF))
    counter = counter + 1
    if counter > 9:
        break
print("\n\n")
# list 10 files with highest average values
counter = 0
print("files with highest average values:")
for file in sorted(file_average, key=file_average.get, reverse=True):
    print(file + " had average value of " + str(file_average[file]))
    counter = counter + 1
    if counter > 9:
        break
print("\n\n")
# list 10 files with lowest average values
counter = 0
print("Files with lowest average values:")
for file in sorted(file_average, key=file_average.get, reverse=False):
    print(file + " had average value " + str(file_average[file]))
    counter = counter + 1
    if counter > 9:
        break


print(str(highest_cloud_file) + " has the most pixels covered by cloud " + str(highest_cloud_value))
print(str(highest_cloud_shadow_file) + " has the most pixels covered by cloud shadow " + str(highest_cloud_shadow_value))
"""
# Out:
# skipping images as 63113 pixels are covered by cloud
# skipping images as 17256 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 57244 pixels are covered by cloud
# skipping images as 63616 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 55440 pixels are covered by cloud
# skipping images as 26812 pixels are covered by cloud
# skipping images as 195942 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9291 pixels are covered by cloud
# skipping images as 22540 pixels are covered by cloud
# skipping image as 40264 pixels are covered by shadow
# skipping images as 56420 pixels are covered by cloud
# skipping images as 25799 pixels are covered by cloud
# skipping images as 11556 pixels are covered by cloud
# skipping images as 86272 pixels are covered by cloud
# skipping images as 40400 pixels are covered by cloud
# skipping images as 41168 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 40344 pixels are covered by shadow
# skipping images as 176503 pixels are covered by cloud
# skipping images as 34992 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 56372 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 141861 pixels are covered by cloud
# skipping images as 196596 pixels are covered by cloud
# skipping image as 21972 pixels are covered by shadow
# skipping images as 119886 pixels are covered by cloud
# skipping image as 40588 pixels are covered by shadow
# skipping images as 14526 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 72950 pixels are covered by cloud
# skipping image as 37452 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 22720 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 30984 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 19800 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 28408 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 191496 pixels are covered by cloud
# skipping images as 16786 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 64008 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 16364 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 37076 pixels are covered by cloud
# skipping images as 98294 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 36652 pixels are covered by shadow
# skipping images as 62216 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 174582 pixels are covered by cloud
# skipping images as 42295 pixels are covered by cloud
# skipping images as 52284 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 11492 pixels are covered by cloud
# skipping images as 17817 pixels are covered by cloud
# skipping image as 13592 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 33488 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6520 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6540 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 46852 pixels are covered by cloud
# skipping images as 56300 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9753 pixels are covered by cloud
# skipping images as 181584 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 23900 pixels are covered by cloud
# skipping images as 10724 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 133601 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 62888 pixels are covered by cloud
# skipping images as 25412 pixels are covered by cloud
# skipping images as 131043 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 86931 pixels are covered by cloud
# skipping images as 145243 pixels are covered by cloud
# skipping images as 119694 pixels are covered by cloud
# skipping images as 63552 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 24408 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 10764 pixels are covered by cloud
# skipping images as 49846 pixels are covered by cloud
# skipping images as 7736 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 13304 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 17144 pixels are covered by cloud
# skipping images as 187311 pixels are covered by cloud
# skipping images as 195573 pixels are covered by cloud
# skipping images as 11916 pixels are covered by cloud
# skipping image as 36264 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 34396 pixels are covered by shadow
# skipping image as 10884 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6884 pixels are covered by cloud
# skipping image as 62932 pixels are covered by shadow
# skipping images as 14448 pixels are covered by cloud
# skipping images as 25780 pixels are covered by cloud
# skipping images as 28276 pixels are covered by cloud
# skipping image as 47592 pixels are covered by shadow
# skipping images as 7856 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 106038 pixels are covered by cloud
# skipping image as 13072 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 64785 pixels are covered by cloud
# skipping image as 32048 pixels are covered by shadow
# skipping images as 62944 pixels are covered by cloud
# skipping image as 39252 pixels are covered by shadow
# skipping image as 31820 pixels are covered by shadow
# skipping images as 192531 pixels are covered by cloud
# skipping image as 12576 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 27100 pixels are covered by shadow
# skipping images as 45808 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 12484 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 176736 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 49304 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 182481 pixels are covered by cloud
# skipping image as 15708 pixels are covered by shadow
# skipping images as 161723 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 57272 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 61800 pixels are covered by cloud
# skipping images as 12408 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 9988 pixels are covered by shadow
# skipping image as 63108 pixels are covered by shadow
# skipping images as 165896 pixels are covered by cloud
# skipping images as 62301 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 53738 pixels are covered by cloud
# skipping images as 161066 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 93993 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 110110 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 187626 pixels are covered by cloud
# skipping images as 196266 pixels are covered by cloud
# skipping images as 55530 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196593 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 136317 pixels are covered by cloud
# skipping images as 50433 pixels are covered by cloud
# skipping images as 54501 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 190206 pixels are covered by cloud
# skipping images as 48750 pixels are covered by cloud
# skipping images as 183636 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 22661 pixels are covered by cloud
# skipping images as 131604 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 52178 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 189600 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 80692 pixels are covered by cloud
# skipping images as 25121 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 187128 pixels are covered by cloud
# skipping images as 106684 pixels are covered by cloud
# skipping images as 51056 pixels are covered by cloud
# skipping images as 188970 pixels are covered by cloud
# skipping images as 11954 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 18747 pixels are covered by cloud
# skipping images as 76574 pixels are covered by cloud
# skipping images as 196536 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 188314 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 162267 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 19995 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 11096 pixels are covered by shadow
# skipping image as 8056 pixels are covered by shadow
# skipping image as 7072 pixels are covered by shadow
# skipping images as 6664 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 121716 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 87138 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 13192 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 14264 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 11496 pixels are covered by shadow
# skipping image as 10136 pixels are covered by shadow
# skipping images as 196319 pixels are covered by cloud
# skipping images as 25068 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 11472 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 63748 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 20972 pixels are covered by shadow
# skipping image as 30720 pixels have sensors errors
# skipping image as 9436 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 13608 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 15976 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 17624 pixels are covered by shadow
# skipping image as 10240 pixels are covered by shadow
# skipping image as 9932 pixels are covered by shadow
# skipping image as 6848 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 18160 pixels are covered by cloud
# skipping images as 117481 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 15298 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 141153 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 176612 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 7610 pixels are covered by shadow
# skipping images as 27056 pixels are covered by cloud
# skipping images as 10324 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 118270 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 56979 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 167986 pixels are covered by cloud
# skipping images as 145360 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 170539 pixels are covered by cloud
# skipping images as 14012 pixels are covered by cloud
# skipping image as 7924 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 16364 pixels are covered by shadow
# skipping image as 11248 pixels are covered by shadow
# skipping image as 8716 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 7188 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195522 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6712 pixels are covered by cloud
# skipping image as 8828 pixels are covered by shadow
# skipping image as 12204 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 13064 pixels are covered by shadow
# skipping image as 12112 pixels are covered by shadow
# skipping image as 11056 pixels are covered by shadow
# skipping images as 61895 pixels are covered by cloud
# skipping images as 22545 pixels are covered by cloud
# skipping images as 189852 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 10484 pixels are covered by cloud
# skipping images as 83555 pixels are covered by cloud
# skipping image as 7364 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 18556 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 30701 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 49847 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 10528 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping image as 7280 pixels are covered by shadow
# skipping images as 114534 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 14836 pixels are covered by shadow
# skipping image as 11248 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 48400 pixels are covered by cloud
# skipping image as 11056 pixels are covered by shadow
# skipping image as 29290 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 13004 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 40727 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 7632 pixels are covered by shadow
# skipping images as 196593 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 14600 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 7349 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 86321 pixels are covered by cloud
# skipping image as 14052 pixels are covered by shadow
# skipping image as 7888 pixels are covered by shadow
# skipping images as 14772 pixels are covered by cloud
# skipping image as 7472 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 19484 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 7084 pixels are covered by shadow
# skipping images as 142116 pixels are covered by cloud
# skipping images as 9460 pixels are covered by cloud
# skipping images as 183373 pixels are covered by cloud
# skipping image as 13544 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 133610 pixels are covered by cloud
# skipping image as 7496 pixels are covered by shadow
# skipping images as 13160 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 113869 pixels are covered by cloud
# skipping image as 11744 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 29682 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 190955 pixels are covered by cloud
# skipping images as 111724 pixels are covered by cloud
# skipping image as 7200 pixels are covered by shadow
# skipping images as 118402 pixels are covered by cloud
# skipping images as 18986 pixels are covered by cloud
# skipping images as 157687 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 188154 pixels are covered by cloud
# skipping images as 78522 pixels are covered by cloud
# skipping images as 120867 pixels are covered by cloud
# skipping images as 123183 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 154281 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 42777 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196467 pixels are covered by cloud
# skipping images as 72003 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 69199 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 16085 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 41601 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195707 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 194826 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 24894 pixels are covered by cloud
# skipping images as 128925 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 194739 pixels are covered by cloud
# skipping images as 126675 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 69742 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196149 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 181131 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 10926 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 188922 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 107406 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 140826 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 161373 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 95634 pixels are covered by cloud
# skipping images as 95210 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 88438 pixels are covered by cloud
# skipping images as 37427 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 6678 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 14445 pixels are covered by cloud
# skipping image as 7235 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 158256 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 18264 pixels are covered by cloud
# skipping images as 187953 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 80266 pixels are covered by cloud
# skipping images as 179604 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 7898 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 153043 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 15783 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 8138 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 105742 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 58105 pixels are covered by cloud
# skipping images as 183765 pixels are covered by cloud
# skipping images as 70350 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 42861 pixels are covered by cloud
# skipping images as 97932 pixels are covered by cloud
# skipping images as 129816 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 44444 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 178144 pixels are covered by cloud
# skipping images as 39006 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 194403 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195102 pixels are covered by cloud
# skipping images as 14319 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 24917 pixels have sensors errors
# skipping images as 49278 pixels are covered by cloud
# skipping images as 151617 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 98505 pixels are covered by cloud
# skipping images as 175122 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 191607 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 21938 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 13161 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 60491 pixels are covered by cloud
# skipping images as 32468 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195189 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 147411 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 27470 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9801 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 35954 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 103851 pixels are covered by cloud
# skipping images as 61062 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 34367 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 10815 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 111849 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 36029 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 42177 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 68467 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 56058 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 58034 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6705 pixels are covered by cloud
# skipping images as 172722 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 24696 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 120255 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 168144 pixels are covered by cloud
# skipping images as 192120 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 45336 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 97686 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 150363 pixels are covered by cloud
# skipping images as 25167 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 49989 pixels are covered by cloud
# skipping images as 195282 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 25926 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 92367 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 191646 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 190419 pixels are covered by cloud
# skipping images as 139059 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 101667 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195879 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 8730 pixels are covered by cloud
# skipping images as 194046 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 114921 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 192606 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6813 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 115285 pixels are covered by cloud
# skipping images as 56271 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 69775 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 142266 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 127761 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 176547 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 82089 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 191028 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 136650 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 185961 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 193038 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 66895 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 97726 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 54495 pixels are covered by cloud
# skipping images as 164439 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# ...
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195573 pixels are covered by cloud
# skipping images as 120168 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 98274 pixels are covered by cloud
# skipping images as 133601 pixels are covered by cloud
# skipping images as 12684 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 35204 pixels have sensors errors
# skipping images as 6740 pixels are covered by cloud
# skipping images as 181584 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 192531 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 106026 pixels are covered by cloud
# skipping images as 143566 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 62944 pixels are covered by cloud
# skipping images as 72942 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9774 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 119656 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 64773 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195942 pixels are covered by cloud
# skipping images as 12156 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 161722 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 49633 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 16522 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 57619 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 191496 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 15920 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9573 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 25141 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 85992 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 42291 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196596 pixels are covered by cloud
# skipping images as 176736 pixels are covered by cloud
# skipping images as 131043 pixels are covered by cloud
# skipping images as 174652 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 62953 pixels are covered by cloud
# skipping images as 62129 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 176539 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 187311 pixels are covered by cloud
# skipping image as 61741 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 30591 pixels have sensors errors
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 24248 pixels are covered by cloud
# skipping images as 182485 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 9315 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 141861 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping image as 11556 pixels are covered by shadow
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 55045 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196218 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 10538 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 43349 pixels are covered by cloud
# skipping images as 8584 pixels are covered by cloud
# skipping images as 167049 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 170388 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 111696 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 173529 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 50442 pixels are covered by cloud
# skipping images as 195723 pixels are covered by cloud
# skipping images as 195030 pixels are covered by cloud
# skipping images as 46069 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 121875 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 71777 pixels are covered by cloud
# skipping images as 116853 pixels are covered by cloud
# skipping images as 14114 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 111849 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 42037 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 69787 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 58002 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 101675 pixels are covered by cloud
# skipping images as 190419 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 6709 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 49989 pixels are covered by cloud
# skipping images as 56243 pixels are covered by cloud
# skipping images as 172722 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195282 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 195102 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 34415 pixels are covered by cloud
# skipping images as 30201 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 14319 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# skipping images as 56058 pixels are covered by cloud
# skipping images as 114925 pixels are covered by cloud
# skipping images as 196608 pixels are covered by cloud
# loaded 4004 files
# skipped 0 files for being outside region of interest
# skipped 2691 files for being cloudy
# skipped 126 files for being in shadow
# skipped 73 files for having too many values which could be sensor errors
# 1114 files remaining
# average sentinel 1 value is 0.06454749548177348
# standard deviation is 0.9959068124648952
# 1th percentile of Sentinel 1 data is 0.0045436350628733635
# 2th percentile of Sentinel 1 data is 0.00557210635393858
# 3th percentile of Sentinel 1 data is 0.006354665383696556
# 4th percentile of Sentinel 1 data is 0.007032571826130152
# 5th percentile of Sentinel 1 data is 0.007643511984497309
# 75th percentile of Sentinel 1 data is 0.08233769983053207
# 80th percentile of Sentinel 1 data is 0.09446438401937485
# 85th percentile of Sentinel 1 data is 0.10945794731378555
# 90th percentile of Sentinel 1 data is 0.13029232621192932
# 95th percentile of Sentinel 1 data is 0.16866406798362732
# 98th percentile of Sentinel 1 data is 0.23613673031330062
# maximum sentinel 1 value seen is 2845.604248046875
# '\ncounter = 0\n# list 10 files with highest max values\nprint("files with highest max values:")\nfor file in sorted(file_max_values, key=file_max_values.get, reverse=True):\n    print(file + " had max value " + str(file_max_values[file]))\n    counter = counter + 1\n    if counter > 9:\n        break\nprint("\n\n")\n# list 10 files with most high values\ncounter = 0\nprint("files with most high values:")\nfor file in sorted(file_high_value_count, key=file_high_value_count.get, reverse=True):\n    print(file + " had " + str(file_high_value_count[file]) + " values over " + str(HIGH_VALUE_CUT_OFF))\n    counter = counter + 1\n    if counter > 9:\n        break\nprint("\n\n")\n# list 10 files with highest average values\ncounter = 0\nprint("files with highest average values:")\nfor file in sorted(file_average, key=file_average.get, reverse=True):\n    print(file + " had average value of " + str(file_average[file]))\n    counter = counter + 1\n    if counter > 9:\n        break\nprint("\n\n")\n# list 10 files with lowest average values\ncounter = 0\nprint("Files with lowest average values:")\nfor file in sorted(file_average, key=file_average.get, reverse=False):\n    print(file + " had average value " + str(file_average[file]))\n    counter = counter + 1\n    if counter > 9:\n        break\n\n\nprint(str(highest_cloud_file) + " has the most pixels covered by cloud " + str(highest_cloud_value))\nprint(str(highest_cloud_shadow_file) + " has the most pixels covered by cloud shadow " + str(highest_cloud_shadow_value))\n'
